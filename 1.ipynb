# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/madhusudhanrao-ppm/devrel-colab/blob/main/1.ipynb)

# %%
# Write your code here
print('Hello, Jupyter!')

a=5
b=10
c=a+b
print('The sum of', a, 'and', b, 'is', c)
# Out:
# Hello, Jupyter!
# The sum of 5 and 10 is 15
